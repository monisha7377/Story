# %% [markdown]
# <a href="https://colab.research.google.com/github/monisha7377/Story/blob/main/Copy_of_TLCS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Setup for TLCS**

# %%
# !pwd
# !ls
# !rm -r *
# !ls
# Out:
# /content
# sample_data

# %%
# !git clone "https://github.com/AndreaVidali/Deep-QLearning-Agent-for-Traffic-Signal-Control"
# Out:
# Cloning into 'Deep-QLearning-Agent-for-Traffic-Signal-Control'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 193 (delta 27), reused 24 (delta 24), pack-reused 147 (from 1)
# Receiving objects: 100% (193/193), 173.28 KiB | 4.03 MiB/s, done.
# Resolving deltas: 100% (96/96), done.

# %%
# !mv /content/Deep-QLearning-Agent-for-Traffic-Signal-Control/TLCS/* /content/
# !rm -r Deep-QLearning-Agent-for-Traffic-Signal-Control

# %%
# !ls -l
# Out:
# total 72
# -rw-r--r-- 1 root root  5157 Feb  6 16:05 generator.py
# drwxr-xr-x 2 root root  4096 Feb  6 16:05 intersection
# -rw-r--r-- 1 root root   978 Feb  6 16:05 memory.py
# -rw-r--r-- 1 root root  3312 Feb  6 16:05 model.py
# -rw-r--r-- 1 root root  1752 Feb  6 16:05 testing_main.py
# -rw-r--r-- 1 root root   258 Feb  6 16:05 testing_settings.ini
# -rw-r--r-- 1 root root  8692 Feb  6 16:05 testing_simulation.py
# -rw-r--r-- 1 root root  2794 Feb  6 16:05 training_main.py
# -rw-r--r-- 1 root root   414 Feb  6 16:05 training_settings.ini
# -rw-r--r-- 1 root root 11990 Feb  6 16:05 training_simulation.py
# -rw-r--r-- 1 root root  4658 Feb  6 16:05 utils.py
# -rw-r--r-- 1 root root  1006 Feb  6 16:05 visualization.py

# %%
# !python --version
# Out:
# Python 3.11.11

# %% [markdown]
# Installing **SUMO TraCI**

# %%
# !add-apt-repository ppa:sumo/stable -y
# !apt-get update -y
# !apt-get install sumo sumo-tools sumo-doc
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/sumo/stable/ubuntu/ jammy main'
# Description:
# SUMO is a highly portable, microscopic traffic simulation package designed to handle large road networks. SUMO is open source, licensed under the EPLv2.
# More info: https://launchpad.net/~sumo/+archive/ubuntu/stable
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/sumo-ubuntu-stable-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/sumo-ubuntu-stable-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/sumo-ubuntu-stable.gpg with fingerprint 7604B28616B7E70EC0E6D840C32412BB1ADB414B
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# ...

# %%
# !pip install traci
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.9/150.9 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pyvirtualdisplay

# %%
# !apt-get update
# !apt-get install -y xvfb x11-utils
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/sumo/stable/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,523 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,907 kB]
# ...

# %%
# !Xvfb :1 -screen 0 1024x768x24   # Start the Xvfb server in the background

# %%
import os
os.environ["DISPLAY"] = ":1"  # Set DISPLAY to the virtual Xvfb display

# %%
from pyvirtualdisplay import Display

# Start a virtual display
display = Display(visible=1, size=(1024, 768))
display.start()

# Explicitly set the DISPLAY environment variable
os.environ['DISPLAY'] = display.display # This line is added
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-8c0051b8c547> in <cell line: 0>()
# ----> 1 from pyvirtualdisplay import Display
#       2
#       3 # Start a virtual display
#       4 display = Display(visible=1, size=(1024, 768))
#       5 display.start()
#
# ModuleNotFoundError: No module named 'pyvirtualdisplay'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# **Starting Training Process**

# %%
import os
os.environ['SUMO_HOME'] = "/usr/share/sumo/"

# %%
# !python training_main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# ...

# %%
# !apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.

# %%
# !sumo --version
# Out:
# /bin/bash: line 1: sumo: command not found

# %% [markdown]
# Check the */models/* directory for output files
